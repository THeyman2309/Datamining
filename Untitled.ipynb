# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# load in the data (only array data)
# E-TABM-1140 and E-TABM-185 for visual metrics (these have many samples and many variables)
# E-MTAB-11134 for clustering metrics (data with 57 samples form inflammatory breast carcinoma and non-inflamatory breast carcinoma)

# E-TABM-1140
dataset1 = pd.read_table("C:\\Users\\tobia\\Documents\\MuTHER_Fat_normalized_31032010_uncondensed_Ids.txt", low_memory=0) 

# E-TABM-185
dataset2 = pd.read_table("C:\\Users\\tobia\\Documents\\E-TABM-185.processed.txt", low_memory=0)

# E-MTAB-11134
dataset3 = pd.read_csv("C:\\Users\\tobia\\Documents\\E-MTAB-11134\\E-MTAB-11134.csv", low_memory=0)

# Idea test performance of DR tools both on visual standpoint and clustering standpoint
# visual metrics: (1) trustworthyness (proportion of points that are near in original data and DR data)
#       (2) normalized stress (measure for the conservation of pairwise distances between points)



# clustering metrics: (1) accuracy, (2) correlation distance matrix and incidence matrix



# run dimensionality reduction on the data and determine whether clustering tendency remains the same
# DRTs to be used: (1)UMAP, (2) t-SNE and (3) PCA

# %%
dataset1.head()
# Out:
#   Hybridization REF TWPID6598_FAT_2_1;TWPID6598_FAT_1_1  \
# 0      Reporter REF           Log2 normalized intensity
# 1      ILMN_1762337                     7.3238290888597
# 2      ILMN_2055271                    7.69364591654941
# 3      ILMN_1736007                    7.52873831011449
# 4      ILMN_2383229                    7.53790566917042
#
#   TWPID3283_FAT_3_1;TWPID3283_FAT_2_1;TWPID3283_FAT_1_1  \
# 0                          Log2 normalized intensity
# 1                                   7.35768625374953
# 2                                   7.52172442974255
# 3                                      7.57108239255
# 4                                   7.61663657222826
#
#   TWPID5553_FAT_1_1;TWPID5553_FAT_2_1 TWPID4015_FAT_1_1;TWPID4015_FAT_2_1  \
# 0           Log2 normalized intensity           Log2 normalized intensity
# 1                    7.38756473870654                    7.44879502502484
# 2                    7.69142480962333                    7.91302993272575
# ...

# %%
# first line is not informative => drop it + transpose + fix rownames and column names

dataset1 = dataset1.iloc[1: , : ]
dataset1.set_index('Hybridization REF', inplace=True)
dataset1 = pd.DataFrame.transpose(dataset1)
dataset1.head()
# Out:
# Hybridization REF                                       ILMN_1762337  \
# TWPID6598_FAT_2_1;TWPID6598_FAT_1_1                  7.3238290888597
# TWPID3283_FAT_3_1;TWPID3283_FAT_2_1;TWPID3283_F...  7.35768625374953
# TWPID5553_FAT_1_1;TWPID5553_FAT_2_1                 7.38756473870654
# TWPID4015_FAT_1_1;TWPID4015_FAT_2_1                 7.44879502502484
# TWPID16101_FAT_2_1;TWPID16101_FAT_1_1               7.44855713171847
#
# Hybridization REF                                       ILMN_2055271  \
# TWPID6598_FAT_2_1;TWPID6598_FAT_1_1                 7.69364591654941
# TWPID3283_FAT_3_1;TWPID3283_FAT_2_1;TWPID3283_F...  7.52172442974255
# TWPID5553_FAT_1_1;TWPID5553_FAT_2_1                 7.69142480962333
# TWPID4015_FAT_1_1;TWPID4015_FAT_2_1                 7.91302993272575
# TWPID16101_FAT_2_1;TWPID16101_FAT_1_1               7.71643223020567
#
# Hybridization REF                                       ILMN_1736007  \
# ...

# %%
 dataset1.describe()
# Out:
# Hybridization REF      ILMN_1762337      ILMN_2055271     ILMN_1736007  \
# count                           825               825              825
# unique                          807               810              814
# top                7.37645537706719  7.72981533661541  7.6064965127375
# freq                              3                 2                2
#
# Hybridization REF      ILMN_2383229      ILMN_1806310      ILMN_1779670  \
# count                           825               825               825
# unique                          814               814               814
# top                7.73309566233173  7.73342023786813  7.58968603052075
# freq                              2                 2                 2
#
# Hybridization REF      ILMN_2321282      ILMN_1671474      ILMN_1772582  \
# count                           825               825               825
# unique                          817               809               808
# ...

# %%
dataset1.shape
# Out:
# (825, 48638)

# %%
dataset2.head()
# Out:
#        Scan REF    1102960533.cel    1102960569.cel    1102960602.cel  \
# 0  Reporter REF        RMA_Signal        RMA_Signal        RMA_Signal
# 1     1007_s_at  5.84601892351365  5.51991851949328  5.62840394392514
# 2       1053_at  5.91140491509603  5.71716004972423  6.24333874332166
# 3        117_at  3.76489572283982  3.73443835587479  3.70490932570258
# 4        121_at  2.46214208083720  2.48762338871821  2.50360190599884
#
#      1102960632.cel    1102960664.cel    1102960695.cel    1102960731.cel  \
# 0        RMA_Signal        RMA_Signal        RMA_Signal        RMA_Signal
# 1  5.62984532216366  5.14810352743488  4.83368732740395  4.61315318001641
# 2   5.9347159603795  6.00681003983379  5.92973808958148   6.1379781807833
# 3  3.73244507113682  3.92706717641208  4.15896576115875  3.83503880401411
# 4  2.46355351510533  2.53077974438703  2.54982105554011  2.48844450510696
#
#      1102960765.cel    1102960797.cel  ...       GSM9850.CEL  \
# ...

# %%
# first line is not informative => drop it + transpose + fix rownames and column names

dataset2 = dataset2.iloc[1: , : ]
dataset2.set_index('Scan REF', inplace=True)
dataset2 = pd.DataFrame.transpose(dataset2)
dataset2.head()
# Out:
# Scan REF               1007_s_at           1053_at            117_at  \
# 1102960533.cel  5.84601892351365  5.91140491509603  3.76489572283982
# 1102960569.cel  5.51991851949328  5.71716004972423  3.73443835587479
# 1102960602.cel  5.62840394392514  6.24333874332166  3.70490932570258
# 1102960632.cel  5.62984532216366   5.9347159603795  3.73244507113682
# 1102960664.cel  5.14810352743488  6.00681003983379  3.92706717641208
#
# Scan REF                  121_at         1255_g_at           1294_at  \
# 1102960533.cel  2.46214208083720  2.07140526422359  8.92880742258999
# 1102960569.cel  2.48762338871821  2.05760882804919  9.54353758559224
# 1102960602.cel  2.50360190599884  2.03955587552279  8.22748048323166
# 1102960632.cel  2.46355351510533  2.04538338700373  9.01694202110817
# 1102960664.cel  2.53077974438703  2.05054392708587  8.67768739726233
#
# Scan REF                 1316_at           1320_at         1405_i_at  \
# ...

# %%
dataset2.describe()
# Out:
# Scan REF         1007_s_at           1053_at            117_at  \
# count                 5896              5896              5896
# unique                5396              5398              5398
# top       10.5321564161537  5.28366836919255  3.67144200879429
# freq                     2                 2                 2
#
# Scan REF            121_at         1255_g_at           1294_at  \
# count                 5896              5896              5896
# unique                5214              5398              5394
# top       2.55737567147112  1.99222071022878  3.56723443947138
# freq                     5                 2                 2
#
# Scan REF          1316_at           1320_at         1405_i_at  \
# count                5896              5896              5896
# unique               5395              5398              5398
# top       3.5988835107859  2.73585103499747  6.50741118963669
# freq                    3                 2                 2
#
# ...

# %%
dataset2.shape
# Out:
# (5896, 22283)

# %%
dataset3.head()
# Out:
#             0        1        2        3        4        5        6        \
# FC04.1.CEL      211     8960      300     9199      118       93     9330
# FC04.2.CEL      180     7066      203     7001       79       86     7063
# FC04.3.CEL      229     9361      282     9409      141       77     9617
# FC09.4.CEL      206     8508      228     8319      114       80     8552
# FC09.5.CEL      186     7411      211     7609      120      128     7676
#
#             7        8        9        ...  1354886  1354887  1354888  \
# FC04.1.CEL      166     9314      169  ...     8106      169     8036
# FC04.2.CEL      123     6927      139  ...     7965      216     7874
# FC04.3.CEL      157     9521      176  ...     8395      184     8454
# FC09.4.CEL      181     8383      189  ...    10069      214    10172
# FC09.5.CEL      160     7548      153  ...     9556      200     9380
#
#             1354889  1354890  1354891  1354892  1354893  1354894  1354895
# ...

# %%
# first column is not informative => drop it + transpose 

dataset3 = dataset3.iloc[: , 1: ]
dataset3 = pd.DataFrame.transpose(dataset3)
dataset3.head()
# Out:
#             0        1        2        3        4        5        6        \
# FC04.1.CEL      211     8960      300     9199      118       93     9330
# FC04.2.CEL      180     7066      203     7001       79       86     7063
# FC04.3.CEL      229     9361      282     9409      141       77     9617
# FC09.4.CEL      206     8508      228     8319      114       80     8552
# FC09.5.CEL      186     7411      211     7609      120      128     7676
#
#             7        8        9        ...  1354886  1354887  1354888  \
# FC04.1.CEL      166     9314      169  ...     8106      169     8036
# FC04.2.CEL      123     6927      139  ...     7965      216     7874
# FC04.3.CEL      157     9521      176  ...     8395      184     8454
# FC09.4.CEL      181     8383      189  ...    10069      214    10172
# FC09.5.CEL      160     7548      153  ...     9556      200     9380
#
#             1354889  1354890  1354891  1354892  1354893  1354894  1354895
# ...

# %%
dataset3.describe()
# Out:
#           0             1           2             3           4        \
# count   57.000000     57.000000   57.000000     57.000000   57.000000
# mean   119.614035   8720.403509  164.964912   8773.192982   84.947368
# std     48.206310   2081.257560   64.008081   2051.370225   31.004850
# min     47.000000   5526.000000   77.000000   5506.000000   40.000000
# 25%     82.000000   7411.000000  109.000000   7531.000000   60.000000
# 50%    106.000000   8453.000000  160.000000   8408.000000   79.000000
# 75%    152.000000   9616.000000  214.000000   9771.000000  112.000000
# max    236.000000  16000.000000  375.000000  16206.000000  203.000000
#
#           5             6           7             8           9        ...  \
# count   57.000000     57.000000   57.000000     57.000000   57.000000  ...
# mean    84.526316   8794.964912  127.403509   8710.403509  126.035088  ...
# std     22.381518   2078.931052   33.510584   2065.556773   33.672246  ...
# ...

# %%
dataset3.shape
# Out:
# (57, 1354896)

# %% [markdown]
# Now that we loaded in the data, we can perform dimensionality reduction
#
# ## dimensionality reduction
# ### UMAP

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import time

# %%
# perform dimensionality reduction on each dataset
# measure time
t0 = time.time()
umap_reduction_1_2 = umap.UMAP(n_components=2).fit_transform(dataset1)

umap_reduction_2_2 = umap.UMAP(n_components=2).fit_transform(dataset2)

umap_reduction_3_2 = umap.UMAP(n_components=2).fit_transform(dataset3)

umap_reduction_3_3 = umap.UMAP(n_components=3).fit_transform(dataset3)
print(f'Running these umap reductions took {time.time() - t0} seconds')
# Out:
# C:\Users\tobia\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:245: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# Running these umap reductions took 323.7401432991028 seconds

# %% [markdown]
# ## t-SNE

# %%
from sklearn.manifold import TSNE
import time
t0 = time.time()

# perform dimensionality reduction on each dataset
tsne_reduction_1_2 = TSNE(n_components=2).fit_transform(dataset1)

tsne_reduction_2_2 = TSNE(n_components=2).fit_transform(dataset2)

tsne_reduction_3_2 = TSNE(n_components=2).fit_transform(dataset3)

# n_components needs to be inferior to 4
tsne_reduction_3_3 = TSNE(n_components=3).fit_transform(dataset3)

print(f'Running these tsne reductions took {time.time() - t0} seconds')
# Out:
# Running these tsne reductions took 210.42245149612427 seconds

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
import time
t0 = time.time()

pca = PCA()

pca_reduction_1 = pca.fit_transform(dataset1)

pca_reduction_2 = pca.fit_transform(dataset2)

pca_reduction_3 = pca.fit_transform(dataset3)

# to make times comparable do pca reduction of dataset 3 once more

pca_reduction_3 = pca.fit_transform(dataset3)

print(f'Running these pca reductions took {time.time() - t0} seconds')
# Out:
# Running these pca reductions took 623.3858797550201 seconds

# %% [markdown]
# ## Analysis for differences in running times

# %%
from sklearn.manifold import TSNE
import umap
from sklearn.decomposition import PCA
import time
pca = PCA()
datasets = [dataset1, dataset2, dataset3]
times = {"value": [], "DR technique": [], "dataset": []}
for index in range(len(datasets)):
    # run every dimensionality reduction three times
    for repitition in range(3):
        # measure time to perform umap reduction and measure time
        t0 = time.time()
        umap.UMAP(n_components=2).fit_transform(datasets[index])
        times["value"].append(time.time() - t0)
        times["DR technique"].append("umap")
        times["dataset"].append(str(index + 1))
        
        # measure time to perform tsne reduction and measure time
        t0 = time.time()
        TSNE(n_components=2).fit_transform(datasets[index])
        times["value"].append(time.time() - t0)
        times["DR technique"].append("tsne")
        times["dataset"].append(str(index + 1))
        
        # measure time to perform pca reduction and measure time
        t0 = time.time()
        pca.fit_transform(datasets[index])
        times["value"].append(time.time() - t0)
        times["DR technique"].append("pca")
        times["dataset"].append(str(index + 1))
        print(times)

# make dataframe of result and write to csv
df = pd.DataFrame(times)
df.to_csv("times.csv")
# Out:
# {'value': [52.67058324813843, 13.077927827835083, 16.041279554367065], 'DR technique': ['umap', 'tsne', 'pca'], 'dataset': ['1', '1', '1']}
# {'value': [52.67058324813843, 13.077927827835083, 16.041279554367065, 24.563793659210205, 12.381368398666382, 11.166464805603027], 'DR technique': ['umap', 'tsne', 'pca', 'umap', 'tsne', 'pca'], 'dataset': ['1', '1', '1', '1', '1', '1']}
# {'value': [52.67058324813843, 13.077927827835083, 16.041279554367065, 24.563793659210205, 12.381368398666382, 11.166464805603027, 24.0210702419281, 11.186865329742432, 11.267701625823975], 'DR technique': ['umap', 'tsne', 'pca', 'umap', 'tsne', 'pca', 'umap', 'tsne', 'pca'], 'dataset': ['1', '1', '1', '1', '1', '1', '1', '1', '1']}
# C:\Users\tobia\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:245: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...

# %% [markdown]
# ## Metrics

# %% [markdown]
# ##### trustworthiness

# %%
#https://towardsdatascience.com/on-the-validating-umap-embeddings-2c8907588175
from sklearn.manifold import trustworthiness

datasets = [[[dataset1, umap_reduction_1_2], [dataset2, umap_reduction_2_2],[dataset3, umap_reduction_3_2]],
            [[dataset1, tsne_reduction_1_2], [dataset2, tsne_reduction_2_2],[dataset3, tsne_reduction_3_2]],
            [[dataset1, pca_reduction_1[:,:2]], [dataset2, pca_reduction_2[:,:2]],[dataset3, pca_reduction_3[:,:2]]]]

trust_scores = [[],[],[]]

# for every DR technique
for i in range(3):
    # for every dataset:
    for j in range(3):
        high_data, low_data = datasets[i][j]
        trust_scores[i].append(trustworthiness(high_data, low_data))

# %%
DR = ['UMAP', 't-SNE', 'PCA']
score_print = [[str(i) for i in trust_scores[j]] for j in range(3)]
for i in range(3):
    print(f"The trustworthiness scores for {DR[i]} were {', '.join(score_print[i])} for datasets 1,2 and 3 respectively")
# Out:
# The trustworthiness scores for UMAP were 0.921637624717184, 0.9946088634151378, 0.9280343716433942 for datasets 1,2 and 3 respectively
# The trustworthiness scores for t-SNE were 0.9476105485701569, 0.9977349465002064, 0.8933762978875761 for datasets 1,2 and 3 respectively
# The trustworthiness scores for PCA were 0.8520790771855643, 0.9005767658434606, 0.8574292875044754 for datasets 1,2 and 3 respectively

# %%
# determine expected values for random data
import random
from sklearn.manifold import trustworthiness

trust = []
stress = []
# check for random one
for i in range(100):
    # make random 20x1000 dataset
    high_data = pd.DataFrame([[random.random() for i in range(1000)] for i in range(20)])
    # make random 20x2 dataset
    low_data = pd.DataFrame([[random.random(), random.random()] for i in range(20)])
    #calculate trustworthiness
    trust.append(trustworthiness(high_data, low_data))
    stress.append(normalized_stress(high_data, low_data))

print(np.mean(trust), np.std(trust)) 
print(np.mean(stress), np.std(stress))
# Out:
# 0.5389833333333334 0.040523583668443414
# 0.9206312886601716 0.005823146379863594

# %% [markdown]
# ##### normalized stress

# %%
# sum((high_dim_i - low_dim_i)**2)/sum(high_dim_i) for i in data
from sklearn.metrics import pairwise

def normalized_stress(data_high, data_low):
    # get pairwise distances high_dimensional data
    high_dist = pairwise.euclidean_distances(data_high)

    # get pairwise distances low_dimensional data
    low_dist = pairwise.euclidean_distances(data_low)
    
    l = data_high.shape[0]
    total = 0
    # get sum of pairwise distances data_high
    for i in range(l):
        for j in range(i + 1,):
            total += high_dist[i][j] ** 2
        
    stress = 0
    # get stress
    for i in range(l):
        for j in range(i + 1,):
            stress += (high_dist[i][j] - low_dist[i][j]) ** 2
    # normalise stress
    return stress / total

# %%
datasets = [[[dataset1, umap_reduction_1_2], [dataset2, umap_reduction_2_2],[dataset3, umap_reduction_3_2]],
            [[dataset1, tsne_reduction_1_2], [dataset2, tsne_reduction_2_2],[dataset3, tsne_reduction_3_2]],
            [[dataset1, pca_reduction_1[:,:2]], [dataset2, pca_reduction_2[:,:2]],[dataset3, pca_reduction_3[:,:2]]]]

stress_scores = [[],[],[]]

# for every DR technique
for i in range(3):
    # for every dataset:
    for j in range(3):
        high_data, low_data = datasets[i][j]
        stress_scores[i].append(normalized_stress(high_data, low_data))

# %%
DR = ['UMAP', 't-SNE', 'PCA']
score_print = [[str(i) for i in stress_scores[j]] for j in range(3)]
for i in range(3):
    print(f"The normalized stress scores for {DR[i]} were {', '.join(score_print[i])} for datasets 1,2 and 3 respectively")
# Out:
# The normalized stress scores for UMAP were 0.8399765761963699, 0.8993401734587501, 0.9999928274887576 for datasets 1,2 and 3 respectively
# The normalized stress scores for t-SNE were 0.2473133762120208, 0.5496279363331533, 0.999749667036924 for datasets 1,2 and 3 respectively
# The normalized stress scores for PCA were 0.25554342278826564, 0.32633080534774184, 0.2680290318207868 for datasets 1,2 and 3 respectively

# %% [markdown]
# ## Clustering

# %% [markdown]
# #### Does the data have clustering tendencies?

# %% [markdown]
# If the hopkins score is above 0.75 the data shows clustering tendencies

# %%
# taken from https://sushildeore99.medium.com/really-what-is-hopkins-statistic-bad1265df4b
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n)
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)

    rand_X = sample(range(0, n, 1), m)

    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0

    return H

# %%
print(hopkins(dataset3))
# Out:
# 0.8064645645107695

# %% [markdown]
# #### Clustering metrics

# %%
# get labels for dataset3
# read in labels
meta_data = pd.read_csv("C:\\Users\\tobia\\Documents\\E-MTAB-11134\\E-MTAB-11134.sdrf.txt", low_memory=0,delimiter='\t')

# make dictionary
dict_labels = {meta_data.iloc[i,0]: meta_data.iloc[i,5] for i in range(57)}
labels = [dict_labels[i] for i in list(dataset3.index)]

# %%
# make functions to evaluate clustering
from sklearn.metrics.pairwise import euclidean_distances

def compute_incidence(clustering_array):
    x = clustering_array
    X = np.tile(x, (x.shape[0], 1))
    Xt = X.transpose()
    incidence = X == Xt
    return(incidence)


def correlation(reduction, cluster):
    
    # make proximity matrix and incidence matrix
    proximity_matrix = euclidean_distances(reduction, reduction)
    incidence_matrix = compute_incidence(cluster)

    # convert matrices to arrays
    proximity_matrix_flat = proximity_matrix.flatten()
    incidence_matrix_flat = incidence_matrix.flatten()

    # get correlation (cor ~= 0.5 => no clustering tendencies)
    pcc = np.corrcoef(proximity_matrix_flat, incidence_matrix_flat)
    return pcc[0,1]



# accuracy based on label (TP + TN)/(TN + FN + FP + TP)
def accuracy(cluster, labels):
    TP, FP, TN, FN = 0, 0, 0, 0

    for i in range(57):
        if cluster[i] == 1 and labels[i] == "inflammatory breast carcinoma" :
            TP += 1
        elif cluster[i] == 1 and labels[i] == "non-inflammatory breast carcinoma":
            FP += 1
        elif labels[i] == "inflammatory breast carcinoma" :
            FN += 1
        elif labels[i] == "non-inflammatory breast carcinoma":
            TN += 1
    return ((TP + TN)/(TN + FN + FP + TP), TP, FP, TN, FN)
compute_incidence(np.array([1,1,1,1,0,0,0]))
# Out:
# array([[ True,  True,  True,  True, False, False, False],
#        [ True,  True,  True,  True, False, False, False],
#        [ True,  True,  True,  True, False, False, False],
#        [ True,  True,  True,  True, False, False, False],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True]])

# %%
# read in the reduced data
ruduced = pd.read_csv("C:\\Users\\tobia\\Documents\\Master_opleiding\\2th year\\datamining\\project\\reductions.csv", low_memory=0)
ruduced
umap_reduction_3_3 = ruduced.iloc[:,[2,3,4]]
tsne_reduction_3_3 = ruduced.iloc[:,[5,6,7]]
pca_reduction_3_3 = ruduced.iloc[:,[8,9,10]]

# %%
from sklearn.cluster import KMeans


umap_ac, tsne_ac, pca_ac, umap_correlation, tsne_correlation, pca_correlation = 0, 0, 0, 0, 0, 0
value,dr,metric = [],[],[]

for i in range(100):
    umap_cluster = KMeans(n_clusters = 2).fit_predict(umap_reduction_3_3)
    tsne_cluster = KMeans(n_clusters = 2).fit_predict(tsne_reduction_3_3)
    pca_cluster = KMeans(n_clusters = 2).fit_predict(pca_reduction_3[:,:3])
    
    ac = accuracy(umap_cluster, labels)[0]
    value.append(ac)
    dr.append("umap")
    metric.append("accuracy")
    umap_ac += ac
    
    ac = accuracy(tsne_cluster, labels)[0]
    value.append(ac)
    dr.append("tsne")
    metric.append("accuracy")
    tsne_ac += ac
    
    ac = accuracy(pca_cluster, labels)[0]
    value.append(ac)
    dr.append("pca")
    metric.append("accuracy")
    pca_ac += ac
    
    cor = correlation(umap_reduction_3_3, umap_cluster)
    value.append(cor)
    dr.append("umap")
    metric.append("correlation")
    umap_correlation += cor
    
    cor = correlation(tsne_reduction_3_3, tsne_cluster)
    value.append(cor)
    dr.append("tsne")
    metric.append("correlation")
    tsne_correlation += cor
    
    cor = correlation(pca_reduction_3[:,:3], pca_cluster)
    value.append(cor)
    dr.append("pca")
    metric.append("correlation")
    pca_correlation += cor
    
print('Average acurracy of umap:', umap_ac/100, '\tAverage correlation umap:', umap_correlation/100)
print('Average acurracy of tsne:', tsne_ac/100, '\tAverage correlation tsne:', tsne_correlation/100)
print('Average acurracy of pca:', pca_ac/100, '\tAverage correlation pca:', pca_correlation/100)
# Out:
# Average acurracy of umap: 0.5049122807017544 	Average correlation umap: -0.6355107905119725
# Average acurracy of tsne: 0.3422807017543866 	Average correlation tsne: -0.7147538580607334
# Average acurracy of pca: 0.5001754385964913 	Average correlation pca: -0.3414198861737562

# %%
# for random data
from sklearn.cluster import KMeans
import random
corr = []
acc = []
for i in range(100):
    # create random points
    data = pd.DataFrame([[random.random(), random.random()] for i in range (100)])
    # add labels randomly
    rand_lab = [i for i in labels]
    random.shuffle(rand_lab)
    # create random clustering
    clusters = KMeans(n_clusters=2).fit_predict(data)
    ac = accuracy(clusters, rand_lab)[0]
    cor = correlation(data, clusters)
    corr.append(cor)
    acc.append(ac)
    
    # adding values to rest of the data
    value.append(ac)
    dr.append("random")
    metric.append("accuracy")
    value.append(cor)
    dr.append("random")
    metric.append("correlation")
    
print(np.mean(corr), np.std(corr))
print(np.mean(acc), np.std(acc))
# Out:
# -0.5270051106003272 0.02692067435611879
# 0.5070175438596491 0.06724129086574317

# %%
# write results to csv
lib = {"value": value, "DR technique": dr, "metric": metric}
df = pd.DataFrame(lib)
df.to_csv("cluster_results.csv")

# %% [markdown]
# write the new dimensions to a csv to read it into rstudio

# %%
# first make list to put in dictionary
umap1 = [i[0] for i in umap_reduction_3_3]
umap2 = [i[1] for i in umap_reduction_3_3]
umap3 = [i[2] for i in umap_reduction_3_3]
tsne1 = [i[0] for i in tsne_reduction_3_3]
tsne2 = [i[1] for i in tsne_reduction_3_3]
tsne3 = [i[2] for i in tsne_reduction_3_3]
pca1 = [i[0] for i in pca_reduction_3]
pca2 = [i[1] for i in pca_reduction_3]
pca3 = [i[2] for i in pca_reduction_3]

dictio = {"label": labels, "umap1" : umap1, "umap2" : umap2, "umap3" : umap3, "tsne1" : tsne1, "tsne2" : tsne2, "tsne3" : tsne3, "pca1" : pca1, "pca2" : pca2, "pca3" : pca3,}

dataf = pd.DataFrame(dictio)
dataf
# Out:
#                                 label     umap1     umap2     umap3  \
# 0       inflammatory breast carcinoma  2.160006  8.502431  0.909782
# 1       inflammatory breast carcinoma  2.235199  8.261634  0.525033
# 2       inflammatory breast carcinoma  1.963087  8.209410  0.705833
# 3       inflammatory breast carcinoma  2.933587  7.996118  1.632629
# 4       inflammatory breast carcinoma  2.884063  8.322863  1.423135
# 5       inflammatory breast carcinoma  3.239152  8.278604  1.637472
# 6       inflammatory breast carcinoma  2.792441  8.704933 -1.096198
# 7       inflammatory breast carcinoma  2.153051  8.107027 -1.065725
# 8       inflammatory breast carcinoma  2.469416  8.529235 -0.999348
# 9       inflammatory breast carcinoma  1.993664  8.587930  0.194095
# 10      inflammatory breast carcinoma  1.866167  8.571263 -0.160059
# 11      inflammatory breast carcinoma  2.360270  8.346621 -1.279770
# 12      inflammatory breast carcinoma  2.036859  8.324702 -0.877402
# ...

# %%
dataf.to_csv("reductions.csv")
